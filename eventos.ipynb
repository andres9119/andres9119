# %% [markdown]
# <a href="https://colab.research.google.com/github/andres9119/andres9119/blob/main/eventos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargar datos de cada hoja en un DataFrame de Pandas
datos = pd.read_excel('notificaciones.xlsx')

# %%
# Ordenar el DataFrame descendientemente por una columna específica, por ejemplo, "Número de Personas Atendidas"
datos_ordenados = datos.sort_values(by='2023', ascending=False)

# Ver los primeros 5 registros del DataFrame ordenado
print(f"Los primeros N registros del año 2023, ordenados descendientemente por 'Número de Personas Atendidas', son:")
datos_ordenados.head(10)
# Out:
# Los primeros N registros del año 2023, ordenados descendientemente por 'Número de Personas Atendidas', son:
#                Departamento       Municipio  \
# 8   54 - Norte de Santander  54347 - Herrán
# 33  54 - Norte de Santander  54347 - Herrán
# 13  54 - Norte de Santander  54347 - Herrán
# 3   54 - Norte de Santander  54347 - Herrán
# 4   54 - Norte de Santander  54347 - Herrán
# 14  54 - Norte de Santander  54347 - Herrán
# 15  54 - Norte de Santander  54347 - Herrán
# 28  54 - Norte de Santander  54347 - Herrán
# 31  54 - Norte de Santander  54347 - Herrán
# 0   54 - Norte de Santander  54347 - Herrán
#
#                                                Evento  2023
# 8   300 - AGRESIONES POR ANIMALES POTENCIALMENTE T...  29.0
# 33                                875 - VCM, VIF, VSX   5.0
# 13  348 - INFECCION RESPIRATORIA AGUDA GRAVE IRAG ...   2.0
# 3            155 - CÁNCER DE LA MAMA Y CUELLO UTERINO   1.0
# 4                                        205 - CHAGAS   1.0
# 14                          356 - INTENTO DE SUICIDIO   1.0
# 15                 360 - INTOXICACIÓN POR PLAGUICIDAS   1.0
# 28                                  620 - PAROTIDITIS   1.0
# 31                          831 - VARICELA INDIVIDUAL   1.0
# 0                             100 - ACCIDENTE OFIDICO   0.0

# %%
# Solicitar al usuario que ingrese la población total
poblacion_total = float(input("Ingrese la población total: "))

# Calcular  total de casos como la sumatoria de los valores en la columna numero de personas atendidas
casos_total = datos_ordenados['2023'].sum()
casos_total
# Out:
# Ingrese la población total: 7841
# 42.0

# %%
# Calcular el tercer cuartil
tercer_cuartil = datos_ordenados['2023'].quantile(0.75)

# Filtrar los datos por encima del tercer cuartil
cuartil_mas_alto = datos_ordenados[datos_ordenados['2023'] > tercer_cuartil]

# %%
# Solicitar la cantidad de población total a analizar
#poblacion_total = int(input("Escriba la cantidad de población total a analizar --> "))

# Calcular el porcentaje de afectación para cada número de personas atendidas
#datos_ordenados.loc[:, 'porcentaje_de_afectacion'] = (cuartil_mas_alto['total atendidos'] / casos_total) * 100

# Mostrar el DataFrame con la nueva columna
#datos_ordenados.head(15)



# Calcular el porcentaje de afectación solo para los registros por encima del tercer cuartil
datos_ordenados.loc[datos_ordenados['2023'] > tercer_cuartil, 'porcentaje_de_afectacion'] = (
    datos_ordenados['2023'] / casos_total * 100
)

datos_ordenados.head()
# Out:
#                Departamento       Municipio  \
# 8   54 - Norte de Santander  54347 - Herrán
# 33  54 - Norte de Santander  54347 - Herrán
# 13  54 - Norte de Santander  54347 - Herrán
# 3   54 - Norte de Santander  54347 - Herrán
# 4   54 - Norte de Santander  54347 - Herrán
#
#                                                Evento  2023  \
# 8   300 - AGRESIONES POR ANIMALES POTENCIALMENTE T...  29.0
# 33                                875 - VCM, VIF, VSX   5.0
# 13  348 - INFECCION RESPIRATORIA AGUDA GRAVE IRAG ...   2.0
# 3            155 - CÁNCER DE LA MAMA Y CUELLO UTERINO   1.0
# 4                                        205 - CHAGAS   1.0
#
#     porcentaje_de_afectacion
# 8                  69.047619
# 33                 11.904762
# 13                  4.761905
# 3                        NaN
# 4                        NaN

# %%
# Crear la nueva columna "magnitud" en el DataFrame
datos_ordenados.loc['magnitud'] = datos_ordenados['porcentaje_de_afectacion'].apply(lambda x: 10 if x >= 50 else (8 if 5 <= x < 50 else (6 if 0.5 <= x < 4.9 else 4)))


datos_trabajo = datos_ordenados[datos_ordenados['porcentaje_de_afectacion'].notna()]

datos_trabajo.head(10)
# Out:
#                Departamento       Municipio  \
# 8   54 - Norte de Santander  54347 - Herrán
# 33  54 - Norte de Santander  54347 - Herrán
# 13  54 - Norte de Santander  54347 - Herrán
#
#                                                Evento  2023  \
# 8   300 - AGRESIONES POR ANIMALES POTENCIALMENTE T...  29.0
# 33                                875 - VCM, VIF, VSX   5.0
# 13  348 - INFECCION RESPIRATORIA AGUDA GRAVE IRAG ...   2.0
#
#     porcentaje_de_afectacion
# 8                  69.047619
# 33                 11.904762
# 13                  4.761905

# %%
0# Crear listas vacías para almacenar los valores ingresados por el usuario
severidad = []
eficacia = []
factibilidad = []

# Iterar sobre los primeros 'n' registros del DataFrame
for i in range(len(datos_trabajo)):
    # Obtener el nombre del subgrupo para mostrarlo en el mensaje
    nombre_subgrupo = datos_trabajo.iloc[i]['Evento']

    # Solicitar la entrada del usuario para cada nueva columna
    valor_severidad = float(input(f"Ingrese el valor de severidad para '{nombre_subgrupo}': "))
    valor_eficacia = float(input(f"Ingrese el valor de eficacia para '{nombre_subgrupo}': "))
    valor_factibilidad = float(input(f"Ingrese el valor de factibilidad para '{nombre_subgrupo}': "))

    # Agregar los valores ingresados a las listas respectivas
    severidad.append(valor_severidad)
    eficacia.append(valor_eficacia)
    factibilidad.append(valor_factibilidad)

# Agregar las listas como nuevas columnas en el DataFrame datos_trabajo
datos_trabajo.loc[:, 'severidad'] = severidad
datos_trabajo.loc[:, 'eficacia'] = eficacia
datos_trabajo.loc[:, 'factibilidad'] = factibilidad

# Mostrar el DataFrame actualizado con las nuevas columnas
print("Datos con las nuevas columnas 'severidad', 'eficacia' y 'factibilidad':")
datos_trabajo
# Out:
# Ingrese el valor de severidad para '300 - AGRESIONES POR ANIMALES POTENCIALMENTE TRANSMISORES DE RABIA': 10
# Ingrese el valor de eficacia para '300 - AGRESIONES POR ANIMALES POTENCIALMENTE TRANSMISORES DE RABIA': 1.5
# Ingrese el valor de factibilidad para '300 - AGRESIONES POR ANIMALES POTENCIALMENTE TRANSMISORES DE RABIA': 1
# Ingrese el valor de severidad para '875 - VCM, VIF, VSX': 8
# Ingrese el valor de eficacia para '875 - VCM, VIF, VSX': 0.5
# Ingrese el valor de factibilidad para '875 - VCM, VIF, VSX': 1
# Ingrese el valor de severidad para '348 - INFECCION RESPIRATORIA AGUDA GRAVE IRAG INUSITADA': 9
# Ingrese el valor de eficacia para '348 - INFECCION RESPIRATORIA AGUDA GRAVE IRAG INUSITADA': 1.5
# Ingrese el valor de factibilidad para '348 - INFECCION RESPIRATORIA AGUDA GRAVE IRAG INUSITADA': 1
# Datos con las nuevas columnas 'severidad', 'eficacia' y 'factibilidad':
# <ipython-input-11-38ffc034f226>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_trabajo.loc[:, 'severidad'] = severidad
# <ipython-input-11-38ffc034f226>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_trabajo.loc[:, 'eficacia'] = eficacia
# <ipython-input-11-38ffc034f226>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_trabajo.loc[:, 'factibilidad'] = factibilidad
#                Departamento       Municipio  \
# 8   54 - Norte de Santander  54347 - Herrán
# 33  54 - Norte de Santander  54347 - Herrán
# 13  54 - Norte de Santander  54347 - Herrán
#
#                                                Evento  2023  \
# 8   300 - AGRESIONES POR ANIMALES POTENCIALMENTE T...  29.0
# 33                                875 - VCM, VIF, VSX   5.0
# 13  348 - INFECCION RESPIRATORIA AGUDA GRAVE IRAG ...   2.0
#
#     porcentaje_de_afectacion  severidad  eficacia  factibilidad
# 8                  69.047619       10.0       1.5           1.0
# 33                 11.904762        8.0       0.5           1.0
# 13                  4.761905        9.0       1.5           1.0

# %%
# Calcular el valor de la nueva columna
puntuacion_hanlon = (datos_trabajo['porcentaje_de_afectacion'] + datos_trabajo['severidad']) * datos_trabajo['eficacia'] * datos_trabajo['factibilidad']

# Convertir la Serie puntuacion_hanlon en un DataFrame
df_puntuacion_hanlon = puntuacion_hanlon.to_frame()

# Agregar la nueva columna al DataFrame con el nombre "puntuación Hanlon" utilizando .loc[]
datos_trabajo.loc[:, 'puntuación Hanlon'] = puntuacion_hanlon

# Mostrar el DataFrame actualizado con la nueva columna
print("Datos con la nueva columna 'puntuación Hanlon':")
datos_trabajo
# Out:
# Datos con la nueva columna 'puntuación Hanlon':
# <ipython-input-12-628413283f30>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_trabajo.loc[:, 'puntuación Hanlon'] = puntuacion_hanlon
#                Departamento       Municipio  \
# 8   54 - Norte de Santander  54347 - Herrán
# 33  54 - Norte de Santander  54347 - Herrán
# 13  54 - Norte de Santander  54347 - Herrán
#
#                                                Evento  2023  \
# 8   300 - AGRESIONES POR ANIMALES POTENCIALMENTE T...  29.0
# 33                                875 - VCM, VIF, VSX   5.0
# 13  348 - INFECCION RESPIRATORIA AGUDA GRAVE IRAG ...   2.0
#
#     porcentaje_de_afectacion  severidad  eficacia  factibilidad  \
# 8                  69.047619       10.0       1.5           1.0
# 33                 11.904762        8.0       0.5           1.0
# 13                  4.761905        9.0       1.5           1.0
#
#     puntuación Hanlon
# 8          118.571429
# 33           9.952381
# 13          20.642857

# %%
# Ordenar el DataFrame por la columna 'puntuación Hanlon' de mayor a menor
df_ordenado = datos_trabajo.sort_values(by='puntuación Hanlon', ascending=False)

# %%
# Seleccionar las columnas que se desean mostrar
columnas_mostrar = ['Municipio', 'Evento',  'puntuación Hanlon']
pd.set_option('display.expand_frame_repr', False)
# Mostrar el DataFrame ordenado con las columnas seleccionadas
df_ordenado[columnas_mostrar]
# Out:
#          Municipio                                             Evento  puntuación Hanlon
# 8   54347 - Herrán  300 - AGRESIONES POR ANIMALES POTENCIALMENTE T...         118.571429
# 13  54347 - Herrán  348 - INFECCION RESPIRATORIA AGUDA GRAVE IRAG ...          20.642857
# 33  54347 - Herrán                                875 - VCM, VIF, VSX           9.952381
